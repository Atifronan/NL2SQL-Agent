# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('rvb_rvc_remittance_9_jun_15_jun_2025.xlsx', sheet_name='Sheet1')
df.head()
# Out:
#   REPORT_DATE             APPROVAL_DATETIME           NR_NUMBER    TXN_ID  \
# 0    6/9/2025  09-JUN-25 12.00.03.330000 AM  CS0000000071093539  740PI1TK
# 1    6/9/2025  09-JUN-25 12.00.04.759000 AM  CS0000000071093390  740PI1VV
# 2    6/9/2025  09-JUN-25 12.00.06.881000 AM  CS0000000071093476  740PI1Y9
# 3    6/9/2025  09-JUN-25 12.00.08.303000 AM  CS0000000071093540  740PI22F
# 4    6/9/2025  09-JUN-25 12.00.08.827000 AM  CS0000000071093449  740PI25C
#
#        CHANNEL                 MERCHANT_PAR               MERCHANT_WALLET_ENC  \
# 0  THIRD PARTY  Q14DB3B89F2593E5120445E40F0  98883FF10BED59545380B339D3ABD9AE
# 1  THIRD PARTY  Q1C7B8A38A139205E0FEA9158E6  5BEFD0E4A2D688482B269DF78E63F443
# 2  THIRD PARTY  Q110AEB21238B66FA9E844CB040  D25D0586E4894933C5C419EF4B1B0357
# 3  THIRD PARTY  Q110AEB21238B66FA9E844CB040  D25D0586E4894933C5C419EF4B1B0357
# 4  THIRD PARTY  Q14DB3B89F2593E5120445E40F0  98883FF10BED59545380B339D3ABD9AE
#
# ...

# %%
df.head(10)
# Out:
#   REPORT_DATE             APPROVAL_DATETIME           NR_NUMBER    TXN_ID  \
# 0    6/9/2025  09-JUN-25 12.00.03.330000 AM  CS0000000071093539  740PI1TK
# 1    6/9/2025  09-JUN-25 12.00.04.759000 AM  CS0000000071093390  740PI1VV
# 2    6/9/2025  09-JUN-25 12.00.06.881000 AM  CS0000000071093476  740PI1Y9
# 3    6/9/2025  09-JUN-25 12.00.08.303000 AM  CS0000000071093540  740PI22F
# 4    6/9/2025  09-JUN-25 12.00.08.827000 AM  CS0000000071093449  740PI25C
# 5    6/9/2025  09-JUN-25 12.00.11.841000 AM  CS0000000071093488  740PI2CG
# 6    6/9/2025  09-JUN-25 12.00.12.450000 AM  CS0000000071093527  740PI2CF
# 7    6/9/2025  09-JUN-25 12.00.18.235000 AM  CS0000000071093450  740PI2OE
# 8    6/9/2025  09-JUN-25 12.00.18.378000 AM  CS0000000071093557  740PI2OF
# 9    6/9/2025  09-JUN-25 12.00.19.217000 AM  CS0000000071093396  740PI2R9
#
#        CHANNEL                 MERCHANT_PAR               MERCHANT_WALLET_ENC  \
# ...

# %%
df = df[['APPROVAL_DATETIME', 'CHANNEL', 'MERCHANT_NAME', 'TXN_AMT', 'FEE_AMT', 'COMM_AMT', 'TXN_STATUS', 'TXN_TRUST_LEVEL', 'TXN_CUSTOMER_SEGMENT', 'PAYMENT_METHOD']]

# %%
df.head()
# Out:
#               APPROVAL_DATETIME      CHANNEL       MERCHANT_NAME  TXN_AMT  \
# 0  09-JUN-25 12.00.03.330000 AM  THIRD PARTY      IFIC Bank Ltd.    600.0
# 1  09-JUN-25 12.00.04.759000 AM  THIRD PARTY                VISA   2600.0
# 2  09-JUN-25 12.00.06.881000 AM  THIRD PARTY  Trust Bank Limited   1000.0
# 3  09-JUN-25 12.00.08.303000 AM  THIRD PARTY  Trust Bank Limited   5000.0
# 4  09-JUN-25 12.00.08.827000 AM  THIRD PARTY      IFIC Bank Ltd.  10200.0
#
#    FEE_AMT  COMM_AMT TXN_STATUS  TXN_TRUST_LEVEL  TXN_CUSTOMER_SEGMENT  \
# 0      NaN       NaN   APPROVED                4                     1
# 1      NaN       NaN   APPROVED                4                     1
# 2      NaN       NaN   APPROVED                4                     1
# 3      NaN       NaN   APPROVED                4                     3
# 4      NaN       NaN   APPROVED                4                     1
#
#                    PAYMENT_METHOD
# 0                         KONADFS
# ...
